# %%
import shutil

shutil.unpack_archive("/content/drive/MyDrive/hocsau1/jpeg-192x192.zip", "data1")
shutil.unpack_archive("/content/drive/MyDrive/hocsau1/jpeg-224x224.zip", "data2")

# %%
shutil.unpack_archive("/content/data2/test1.zip",'/content/data2/jpeg-224x224/')

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, Sequential
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import AdamW

# Thiết lập tham số
im_height, im_width, batch_size, epochs = 224, 224, 128, 25
data_path = 'data2/jpeg-224x224/'
os.makedirs(data_path, exist_ok=True)

# Data augmentation cho train - Thêm brightness_range
train_image_generator = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.5, 1.5],  # Thêm điều chỉnh độ sáng (0.5 = tối hơn, 1.5 = sáng hơn)
    fill_mode='nearest'
)

# Chỉ rescale cho validation
val_image_generator = ImageDataGenerator(rescale=1./255)

# Thu thập dữ liệu train
train_base_path = 'data2/jpeg-224x224/train/'
all_train_images = []
image_extensions = ['.jpg', '.png', '.jpeg']
for dp, dn, filenames in os.walk(train_base_path):
    label = os.path.basename(dp)
    all_train_images.extend([(os.path.join(dp, f), label) for f in filenames
                            if os.path.splitext(f)[1].lower() in image_extensions])

if not all_train_images:
    print("Không tìm thấy ảnh nào trong thư mục train!")
    exit()
print(f"Tổng số ảnh train: {len(all_train_images)}")

train_df = pd.DataFrame({'filename': [img[0] for img in all_train_images],
                        'class': [img[1] for img in all_train_images]})

# Tạo generator cho train
train_data_gen = train_image_generator.flow_from_dataframe(
    dataframe=train_df,
    x_col='filename',
    y_col='class',
    batch_size=batch_size,
    shuffle=True,
    target_size=(im_height, im_width),
    class_mode='categorical'
)

# Tạo generator cho validation
val_dir = os.path.join(data_path, "val/")
if not os.path.exists(val_dir):
    print("Thư mục val/ không tồn tại! Vui lòng tạo thư mục và thêm dữ liệu.")
    exit()

val_data_gen = val_image_generator.flow_from_directory(
    directory=val_dir,
    batch_size=batch_size,
    shuffle=False,
    target_size=(im_height, im_width),
    class_mode='categorical'
)

# Tạo mô hình DenseNet121
covn_base = tf.keras.applications.DenseNet121(weights='imagenet', include_top=False,
                                            input_shape=(224, 224, 3))
covn_base.trainable = True
for layer in covn_base.layers[:-150]:
    layer.trainable = False

model = Sequential([
    covn_base,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(1024, activation='relu', kernel_regularizer=l2(0.02)),  # Thêm lớp Dense mới
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(512, activation='relu', kernel_regularizer=l2(0.02)),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(len(train_data_gen.class_indices), activation='softmax',
                kernel_regularizer=l2(0.02))
])

# In tóm tắt mô hình
model.summary()

# Compile mô hình
model.compile(
    optimizer=AdamW(learning_rate=0.0001, weight_decay=0.01, clipnorm=1.0),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=["accuracy"]
)

# Callbacks
callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1),
    ModelCheckpoint(filepath='best_model.keras', monitor='val_loss',
                   save_best_only=True, verbose=1),
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)
]

# Tính steps
steps_per_epoch = train_data_gen.n // batch_size
validation_steps = val_data_gen.n // batch_size

print(f"Số mẫu train: {train_data_gen.n}")
print(f"Steps per epoch: {steps_per_epoch}")
print(f"Số mẫu validation: {val_data_gen.n}")
print(f"Validation steps: {validation_steps}")

# Huấn luyện với dataset lặp lại
train_dataset = tf.data.Dataset.from_generator(
    lambda: train_data_gen,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, im_height, im_width, 3], [None, len(train_data_gen.class_indices)])
).repeat()

val_dataset = tf.data.Dataset.from_generator(
    lambda: val_data_gen,
    output_types=(tf.float32, tf.float32),
    output_shapes=([None, im_height, im_width, 3], [None, len(val_data_gen.class_indices)])
).repeat()

history = model.fit(
    train_dataset,
    steps_per_epoch=steps_per_epoch,
    epochs=epochs,
    validation_data=val_dataset,
    validation_steps=validation_steps,
    callbacks=callbacks
)

# Vẽ biểu đồ train và validation
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label='Train Loss')
plt.plot(history.history["val_loss"], label='Val Loss')
plt.legend()
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label='Train Accuracy')
plt.plot(history.history["val_accuracy"], label='Val Accuracy')
plt.legend()
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.savefig('train_val_metrics.png')
plt.close()

# Dự đoán trên ảnh test
test_images = [
    "/content/data2/jpeg-224x224/test/003882deb.jpeg",
    "/content/data1/jpeg-192x192/test/0021f0d33.jpeg",
    "/content/data2/jpeg-224x224/test/004b88e09.jpeg",
    "/content/drive/MyDrive/Hình/nho.jpg",
    "/content/drive/MyDrive/Hình/hd.jpg",
    "/content/drive/MyDrive/Hình/lili.jpg"
]

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
axes = axes.flatten()
class_indices = train_data_gen.class_indices
inverse_dict = {v: k for k, v in class_indices.items()}

for ax, img_path in zip(axes, test_images):
    if os.path.exists(img_path):
        img = Image.open(img_path).resize((224, 224))
        img_array = np.array(img) / 255.0
        img_batch = np.expand_dims(img_array, 0)
        result = model.predict(img_batch)
        predict_class = np.argmax(result)
        predicted_label = inverse_dict[predict_class]
        ax.imshow(img)
        ax.set_title(f"{predicted_label}\nConf: {result[0][predict_class]:.2f}")
        ax.axis('off')
    else:
        ax.text(0.5, 0.5, "Image not found", ha='center', va='center')
        ax.axis('off')

plt.tight_layout()
plt.savefig('test_predictions.png')
plt.close()

# Kiểm tra độ chính xác trên tập test
test_dir = os.path.join(data_path, "test1/")
if not os.path.exists(test_dir):
    print("Thư mục test/ không tồn tại! Vui lòng tạo thư mục và thêm dữ liệu.")
else:
    test_image_generator = ImageDataGenerator(rescale=1./255)
    test_data_gen = test_image_generator.flow_from_directory(
        directory=test_dir,
        batch_size=batch_size,
        shuffle=False,
        target_size=(im_height, im_width),
        class_mode='categorical'
    )

    test_steps = test_data_gen.n // batch_size
    test_dataset = tf.data.Dataset.from_generator(
        lambda: test_data_gen,
        output_types=(tf.float32, tf.float32),
        output_shapes=([None, im_height, im_width, 3], [None, len(test_data_gen.class_indices)])
    ).repeat()

    print(f"Số mẫu test: {test_data_gen.n}")
    print(f"Test steps: {test_steps}")
    test_loss, test_accuracy = model.evaluate(test_dataset, steps=test_steps)
    print(f"Độ chính xác trên tập test: {test_accuracy * 100:.2f}%")
    print(f"Loss trên tập test: {test_loss:.4f}")

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot([test_loss], label='Test Loss', marker='o')
    plt.legend()
    plt.title('Test Loss')
    plt.xlabel('Evaluation')
    plt.ylabel('Loss')

    plt.subplot(1, 2, 2)
    plt.plot([test_accuracy], label='Test Accuracy', marker='o')
    plt.legend()
    plt.title('Test Accuracy')
    plt.xlabel('Evaluation')
    plt.ylabel('Accuracy')
    plt.savefig('test_metrics.png')
    plt.close()
# Out:
# Tổng số ảnh train: 12627
# Found 12627 validated image filenames belonging to 104 classes.
# Found 3674 images belonging to 104 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ densenet121 (Functional)             │ (None, 7, 7, 1024)          │       7,037,504 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1024)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 104)                 │          53,352 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,675,496 (33.09 MB)
#  Trainable params: 4,995,816 (19.06 MB)
#  Non-trainable params: 3,679,680 (14.04 MB)
# Số mẫu train: 12627
# Steps per epoch: 98
# Số mẫu validation: 3674
# Validation steps: 28
# Epoch 1/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.0228 - loss: 41.7123
# Epoch 1: val_loss improved from inf to 35.00232, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 305s 2s/step - accuracy: 0.0231 - loss: 41.6923 - val_accuracy: 0.2882 - val_loss: 35.0023 - learning_rate: 1.0000e-04
# Epoch 2/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1700 - loss: 34.3204
# Epoch 2: val_loss improved from 35.00232 to 29.05938, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 251s 2s/step - accuracy: 0.1704 - loss: 34.3054 - val_accuracy: 0.4729 - val_loss: 29.0594 - learning_rate: 1.0000e-04
# Epoch 3/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3045 - loss: 28.7646
# Epoch 3: val_loss improved from 29.05938 to 24.47272, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.3048 - loss: 28.7527 - val_accuracy: 0.5939 - val_loss: 24.4727 - learning_rate: 1.0000e-04
# Epoch 4/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4172 - loss: 24.3417
# Epoch 4: val_loss improved from 24.47272 to 20.92725, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 195s 2s/step - accuracy: 0.4173 - loss: 24.3327 - val_accuracy: 0.6523 - val_loss: 20.9272 - learning_rate: 1.0000e-04
# Epoch 5/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4896 - loss: 20.8662
# Epoch 5: val_loss improved from 20.92725 to 18.01053, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 193s 2s/step - accuracy: 0.4897 - loss: 20.8587 - val_accuracy: 0.7050 - val_loss: 18.0105 - learning_rate: 1.0000e-04
# Epoch 6/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5363 - loss: 17.9855
# Epoch 6: val_loss improved from 18.01053 to 15.52471, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.5365 - loss: 17.9791 - val_accuracy: 0.7403 - val_loss: 15.5247 - learning_rate: 1.0000e-04
# Epoch 7/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5888 - loss: 15.5283
# Epoch 7: val_loss improved from 15.52471 to 13.44622, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.5889 - loss: 15.5231 - val_accuracy: 0.7572 - val_loss: 13.4462 - learning_rate: 1.0000e-04
# Epoch 8/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6240 - loss: 13.4634
# Epoch 8: val_loss improved from 13.44622 to 11.61074, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.6241 - loss: 13.4586 - val_accuracy: 0.7814 - val_loss: 11.6107 - learning_rate: 1.0000e-04
# Epoch 9/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6608 - loss: 11.6273
# Epoch 9: val_loss improved from 11.61074 to 10.05512, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 184s 2s/step - accuracy: 0.6609 - loss: 11.6234 - val_accuracy: 0.7899 - val_loss: 10.0551 - learning_rate: 1.0000e-04
# Epoch 10/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6909 - loss: 10.0537
# Epoch 10: val_loss improved from 10.05512 to 8.67133, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 194s 2s/step - accuracy: 0.6909 - loss: 10.0504 - val_accuracy: 0.8102 - val_loss: 8.6713 - learning_rate: 1.0000e-04
# Epoch 11/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7173 - loss: 8.7180
# Epoch 11: val_loss improved from 8.67133 to 7.51233, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.7173 - loss: 8.7151 - val_accuracy: 0.8204 - val_loss: 7.5123 - learning_rate: 1.0000e-04
# Epoch 12/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7344 - loss: 7.5943
# Epoch 12: val_loss improved from 7.51233 to 6.57991, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 187s 2s/step - accuracy: 0.7345 - loss: 7.5916 - val_accuracy: 0.8167 - val_loss: 6.5799 - learning_rate: 1.0000e-04
# Epoch 13/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7533 - loss: 6.6139
# Epoch 13: val_loss improved from 6.57991 to 5.71598, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - accuracy: 0.7534 - loss: 6.6117 - val_accuracy: 0.8291 - val_loss: 5.7160 - learning_rate: 1.0000e-04
# Epoch 14/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7616 - loss: 5.7674
# Epoch 14: val_loss improved from 5.71598 to 5.00684, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.7617 - loss: 5.7655 - val_accuracy: 0.8378 - val_loss: 5.0068 - learning_rate: 1.0000e-04
# Epoch 15/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7832 - loss: 5.0645
# Epoch 15: val_loss improved from 5.00684 to 4.40668, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.7833 - loss: 5.0629 - val_accuracy: 0.8409 - val_loss: 4.4067 - learning_rate: 1.0000e-04
# Epoch 16/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7891 - loss: 4.4731
# Epoch 16: val_loss improved from 4.40668 to 3.90955, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 185s 2s/step - accuracy: 0.7892 - loss: 4.4717 - val_accuracy: 0.8455 - val_loss: 3.9096 - learning_rate: 1.0000e-04
# Epoch 17/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8053 - loss: 3.9685
# Epoch 17: val_loss improved from 3.90955 to 3.46307, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 193s 2s/step - accuracy: 0.8054 - loss: 3.9673 - val_accuracy: 0.8517 - val_loss: 3.4631 - learning_rate: 1.0000e-04
# Epoch 18/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8313 - loss: 3.5151
# Epoch 18: val_loss improved from 3.46307 to 3.12935, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8313 - loss: 3.5142 - val_accuracy: 0.8579 - val_loss: 3.1294 - learning_rate: 1.0000e-04
# Epoch 19/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8231 - loss: 3.1835
# Epoch 19: val_loss improved from 3.12935 to 2.83285, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8232 - loss: 3.1825 - val_accuracy: 0.8545 - val_loss: 2.8329 - learning_rate: 1.0000e-04
# Epoch 20/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8358 - loss: 2.8666
# Epoch 20: val_loss improved from 2.83285 to 2.56648, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.8359 - loss: 2.8658 - val_accuracy: 0.8635 - val_loss: 2.5665 - learning_rate: 1.0000e-04
# Epoch 21/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8498 - loss: 2.6013
# Epoch 21: val_loss improved from 2.56648 to 2.34878, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 193s 2s/step - accuracy: 0.8498 - loss: 2.6008 - val_accuracy: 0.8638 - val_loss: 2.3488 - learning_rate: 1.0000e-04
# Epoch 22/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8533 - loss: 2.4006
# Epoch 22: val_loss improved from 2.34878 to 2.17754, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8533 - loss: 2.4000 - val_accuracy: 0.8663 - val_loss: 2.1775 - learning_rate: 1.0000e-04
# Epoch 23/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8675 - loss: 2.2025
# Epoch 23: val_loss improved from 2.17754 to 2.02034, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.8675 - loss: 2.2021 - val_accuracy: 0.8725 - val_loss: 2.0203 - learning_rate: 1.0000e-04
# Epoch 24/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8768 - loss: 2.0263
# Epoch 24: val_loss improved from 2.02034 to 1.89200, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 185s 2s/step - accuracy: 0.8768 - loss: 2.0260 - val_accuracy: 0.8739 - val_loss: 1.8920 - learning_rate: 1.0000e-04
# Epoch 25/25
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8723 - loss: 1.9115
# Epoch 25: val_loss improved from 1.89200 to 1.79483, saving model to best_model.keras
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.8723 - loss: 1.9112 - val_accuracy: 0.8714 - val_loss: 1.7948 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 25.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Found 1282 images belonging to 104 classes.
# Số mẫu test: 1282
# Test steps: 10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - accuracy: 0.8778 - loss: 1.7689
# Độ chính xác trên tập test: 87.66%
# Loss trên tập test: 1.7802
